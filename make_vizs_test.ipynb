# %%
import pandas as pd
import altair as alt
import numpy as np
from helper_funks2 import show_me
import matplotlib.pyplot as plt
import altair_viewer
import altair_saver
from IPython.display import Image

# %%
df_ainize_bleurt = pd.read_csv('evals/ainize_bleurtScores.csv').melt(var_name='column')
df_ainize_noir = pd.read_csv('evals/ainize_noirScores.csv').melt(var_name='column')
df_ainize_rouge = pd.read_csv('evals/ainize_rougeScores.csv').melt(var_name='column')

# %%
alt.renderers.enable('jupyterlab')
alt.data_transformers.disable_max_rows()
source = pd.DataFrame(df_ainize_bleurt)    
bar = show_me(source, "ainize_bleurtScores")

bar.save("bar.png")
Image("bar.png")

# %% [markdown]
# ![bar](./bar.svg)
